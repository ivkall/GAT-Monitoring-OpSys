# %%
from custom_gat.train_and_test_gat import *
from custom_gcn.train_and_test_gcn import *
import sys
import os
import warnings

warnings.filterwarnings('ignore')
# sys.stdout = open(os.devnull, 'w')
# Out:
# 2024-04-17 13:42:12.540485: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-17 13:42:13.694701: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # GAT Tests

# %% [markdown]
# ## Noddöd PLC

# %%
run_gat_model(train_interval_data="standard_100_time-1.3.pkl",
              test_interval_data="noddöd_PLC_100_time-3.4.pkl",
              test_labels="noddöd_PLC_labels.txt",
              gat_epochs=100,
              gat_batches=32,
              gat_lr=0.01,
              autoencoder_epochs=200,
              train=True,
              save_model=True,
              plot_features=True,
              test_individual=True)
# Out:
# Epoch [1/100], Loss: 2258.8601989746094
# Epoch [2/100], Loss: 1377.7565612792969
# Epoch [3/100], Loss: 2730.4613037109375
# Epoch [4/100], Loss: 1744.8816833496094
# Epoch [5/100], Loss: 1873.5883483886719
# Epoch [6/100], Loss: 1497.0800170898438
# Epoch [7/100], Loss: 995.1602020263672
# Epoch [8/100], Loss: 2024.4320526123047
# Epoch [9/100], Loss: 1005.8101959228516
# Epoch [10/100], Loss: 1081.310806274414
# Epoch [11/100], Loss: 912.0781402587891
# Epoch [12/100], Loss: 646.9222106933594
# Epoch [13/100], Loss: 413.1475067138672
# Epoch [14/100], Loss: 262.1107978820801
# Epoch [15/100], Loss: 178.98088836669922
# Epoch [16/100], Loss: 134.32083129882812
# Epoch [17/100], Loss: 105.25430679321289
# Epoch [18/100], Loss: 87.5456371307373
# Epoch [19/100], Loss: 75.81639862060547
# Epoch [20/100], Loss: 68.02016258239746
# Epoch [21/100], Loss: 65.52710056304932
# Epoch [22/100], Loss: 143.7195339202881
# Epoch [23/100], Loss: 150.5279541015625
# ...

# %% [markdown]
# ## Noddöd PLC Ones

# %%
run_gat_model(train_interval_data="standard_100_time-1.3_ones.pkl",
              test_interval_data="noddöd_PLC_100_time-3.4_ones.pkl",
              test_labels="noddöd_PLC_labels.txt",
              gat_epochs=100,
              gat_batches=32,
              gat_lr=0.01,
              autoencoder_epochs=200,
              train=True,
              save_model=True,
              plot_features=True,
              test_individual=True)
# Out:
# Epoch [1/100], Loss: 3555.442138671875
# Epoch [2/100], Loss: 880.8548049926758
# Epoch [3/100], Loss: 750.3038940429688
# Epoch [4/100], Loss: 460.9123840332031
# Epoch [5/100], Loss: 439.21763610839844
# Epoch [6/100], Loss: 3972.0018920898438
# Epoch [7/100], Loss: 2877.299285888672
# Epoch [8/100], Loss: 943.9698486328125
# Epoch [9/100], Loss: 965.0549163818359
# Epoch [10/100], Loss: 545.123291015625
# Epoch [11/100], Loss: 438.75440979003906
# Epoch [12/100], Loss: 331.74222564697266
# Epoch [13/100], Loss: 259.83836364746094
# Epoch [14/100], Loss: 231.1802635192871
# Epoch [15/100], Loss: 195.6974639892578
# Epoch [16/100], Loss: 179.98651504516602
# Epoch [17/100], Loss: 171.5277328491211
# Epoch [18/100], Loss: 160.23848342895508
# Epoch [19/100], Loss: 157.63905334472656
# Epoch [20/100], Loss: 153.80243301391602
# Epoch [21/100], Loss: 151.5069122314453
# Epoch [22/100], Loss: 150.15979385375977
# Epoch [23/100], Loss: 149.09040451049805
# ...

# %% [markdown]
# ## Noddöd IO PLC

# %%
run_gat_model(train_interval_data="standard_100_time-1.3.pkl",
              test_interval_data="noddöd_IO_PLC_100_time-0.5.pkl",
              test_labels="noddöd_IO_PLC_labels.txt",
              gat_epochs=150,
              gat_batches=32,
              gat_lr=0.01,
              autoencoder_epochs=150,
              train=False,
              save_model=False,
              plot_features=True,
              test_individual=True,
              exclusion_percentile=5)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# ...

# %% [markdown]
# ## Noddöd IO PLC Ones

# %%
run_gat_model(train_interval_data="standard_100_time-1.3_ones.pkl",
              test_interval_data="noddöd_IO_PLC_100_time-0.5_ones.pkl",
              test_labels="noddöd_IO_PLC_labels.txt",
              gat_epochs=150,
              gat_batches=32,
              gat_lr=0.01,
              autoencoder_epochs=300,
              train=False,
              save_model=False,
              plot_features=True,
              test_individual=True,
              exclusion_percentile=10)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# ...

# %% [markdown]
# ## Packetloss 70

# %%
run_gat_model(one_graph_data="standard_1_big.pkl",
              train_interval_data="standard_100_time-1.3.pkl",
              test_interval_data="packetloss_70_100_time-0.9.pkl",
              gat_epochs=50,
              gat_batches=32,
              gat_lr=0.01,
              autoencoder_epochs=100,
              train=True,
              save_model=False,
              plot_features=True,
              test_individual=True)

# %% [markdown]
# ## Kabelbrott IO

# %%
run_gat_model(train_interval_data="standard_100_time-1.3.pkl",
              test_interval_data="kabelbrott_IO_100_time-0.4.pkl",
              test_labels="kabelbrott_IO_labels.txt",
              gat_epochs=50,
              gat_batches=32,
              gat_lr=0.01,
              autoencoder_epochs=100,
              train=False,
              save_model=False,
              plot_features=True,
              test_individual=True)
# Out:
# 2024-04-17 13:02:38.196682: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-17 13:02:38.197513: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# ...

# %% [markdown]
# ## Kabelbrott IO Ones

# %%
run_gat_model(train_interval_data="standard_100_time-1.3_ones.pkl",
              test_interval_data="kabelbrott_IO_100_time-0.4_ones.pkl",
              test_labels="kabelbrott_IO_labels.txt",
              gat_epochs=50,
              gat_batches=32,
              gat_lr=0.01,
              autoencoder_epochs=100,
              train=False,
              save_model=False,
              plot_features=True,
              test_individual=True)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# ...

# %% [markdown]
# # GCN Tests

# %% [markdown]
# ## Noddöd PLC

# %%
run_gcn_model(train_interval_data="standard_100_time-1.3.pkl",
              test_interval_data="noddöd_PLC_100_time-3.4.pkl",
              test_labels="noddöd_PLC_labels.txt",
              autoencoder_epochs=200,
              train=True,
              save_model=True,
              test_individual=True)
# Out:
# 168
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0545 - val_loss: 0.0335
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - loss: 0.0598 - val_loss: 0.0290
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 648ms/step - loss: 0.0561 - val_loss: 0.0254
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - loss: 0.0529 - val_loss: 0.0212
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 0.0489 - val_loss: 0.0159
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - loss: 0.0438 - val_loss: 0.0106
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - loss: 0.0378 - val_loss: 0.0080
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 0.0338 - val_loss: 0.0087
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - loss: 0.0319 - val_loss: 0.0094
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - loss: 0.0301 - val_loss: 0.0094
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - loss: 0.0273 - val_loss: 0.0090
# Epoch 12/200
# ...

# %% [markdown]
# ## Noddöd PLC Ones

# %%
run_gcn_model(train_interval_data="standard_100_time-1.3_ones.pkl",
              test_interval_data="noddöd_PLC_100_time-3.4_ones.pkl",
              test_labels="noddöd_PLC_labels.txt",
              autoencoder_epochs=200,
              train=True,
              save_model=True,
              test_individual=True)
# Out:
# 168
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.9988 - val_loss: 1.0729
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - loss: 1.0378 - val_loss: 0.8758
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 0.8843 - val_loss: 0.6983
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - loss: 0.7227 - val_loss: 0.5441
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - loss: 0.5784 - val_loss: 0.4780
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step - loss: 0.5041 - val_loss: 0.5212
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 739ms/step - loss: 0.5295 - val_loss: 0.5553
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step - loss: 0.5526 - val_loss: 0.5128
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 765ms/step - loss: 0.4968 - val_loss: 0.4279
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 567ms/step - loss: 0.4139 - val_loss: 0.3879
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 638ms/step - loss: 0.4002 - val_loss: 0.3988
# Epoch 12/200
# ...

# %% [markdown]
# ## Noddöd IO PLC

# %%
run_gcn_model(train_interval_data="standard_100_time-1.3.pkl",
              test_interval_data="noddöd_IO_PLC_100_time-0.5.pkl",
              test_labels="noddöd_IO_PLC_labels.txt",
              autoencoder_epochs=100,
              train=False,
              save_model=False,
              test_individual=True)
# Out:
# 168
# 2024-04-17 13:41:19.892321: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-17 13:41:19.893115: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# ...

# %% [markdown]
# ## Noddöd IO PLC Ones

# %%
run_gcn_model(train_interval_data="standard_100_time-1.3_ones.pkl",
              test_interval_data="noddöd_IO_PLC_100_time-0.5_ones.pkl",
              test_labels="noddöd_IO_PLC_labels.txt",
              autoencoder_epochs=100,
              train=False,
              save_model=False,
              test_individual=True)
# Out:
# 168
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# ...

# %% [markdown]
# ## Kabelbrott IO

# %%
run_gcn_model(train_interval_data="standard_100_time-1.3.pkl",
              test_interval_data="kabelbrott_IO_100_time-0.4.pkl",
              test_labels="kabelbrott_IO_labels.txt",
              autoencoder_epochs=100,
              train=False,
              save_model=False,
              test_individual=True)
# Out:
# 168
# 2024-04-17 13:42:50.552741: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-17 13:42:50.553900: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# ...

# %% [markdown]
# ## Kabelbrott IO Ones

# %%
run_gcn_model(train_interval_data="standard_100_time-1.3_ones.pkl",
              test_interval_data="kabelbrott_IO_100_time-0.4_ones.pkl",
              test_labels="kabelbrott_IO_labels.txt",
              autoencoder_epochs=100,
              train=False,
              save_model=False,
              test_individual=True)
# Out:
# 168
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# ...
